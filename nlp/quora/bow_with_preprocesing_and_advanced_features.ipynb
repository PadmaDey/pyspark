# %%
import numpy as np 
import pandas as pd
import matplotlib as plt
import seaborn as sns

import re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atharvabhide/Quora-Question-Pair-Similarity/refs/heads/main/notebooks/train.csv")
df.sample(5)
# Out:
#             id    qid1    qid2  \
# 79703    79703  135647  135648
# 248383  248383  361798  361799
# 346638  346638  475010  475011
# 201064  201064  302991  302992
# 42613    42613   76764   76765
#
#                                                 question1  \
# 79703                   Data monetization in IT industry?
# 248383              Does scalar quantity have directions?
# 346638  How do I create a continually updating drop do...
# 201064            How many ounces are in a quarter pound?
# 42613   Did Stephen Hawking really work in the TV show...
#
#                                                 question2  is_duplicate
# 79703   Why would a guy suddenly stop messaging me aft...             0
# 248383                What is a Pacojet machine used for?             0
# 346638       How do you create a drop down list in Excel?             0
# 201064       How many tablespoons are in one fluid ounce?             0
# 42613   How did Stephen Hawking like working in the TV...             0

# %%
new_df = df.sample(30000, random_state=2)
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  What is the best marketing automation tool for...
# 115086  I am poor but I want to invest. What should I do?
# 327711  I am from India and live abroad. I met a guy f...
# 367788  Why do so many people in the U.S. hate the sou...
# 151235                Consequences of Bhopal gas tragedy?
#
#                                                 question2  is_duplicate
# 398782  What is the best marketing automation tool for...             1
# 115086  I am quite poor and I want to be very rich. Wh...             0
# 327711  T.I.E.T to Thapar University to Thapar Univers...             0
# 367788  My boyfriend doesnt feel guilty when he hurts ...             0
# 151235  What was the reason behind the Bhopal gas trag...             0
